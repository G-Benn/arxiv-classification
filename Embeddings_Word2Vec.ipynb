# %% [markdown]
# Experimentation and initial test runs to generate the embeddings for the full text of articles

# %%
import pandas as pd
import gensim as gs
import sklearn as sk
import numpy as np
from gensim.models import Word2Vec

# %%
import gensim
assert gensim.models.doc2vec.FAST_VERSION > -1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-1a0cb6d0a2e0> in <module>
#       1 import gensim
# ----> 2 assert gensim.models.doc2vec.FAST_VERSION > -1
#
# AssertionError:

# %%
info_df = pd.read_pickle('test_src/info_df.pkl')
reduced_categories_df = pd.read_pickle('test_src/full_reduced_df.pkl')
expanded_categories_df = pd.read_pickle('test_src/full_expanded_df.pkl')

# %%
test_paper = info_df['text'][1]
print(test_paper)
# Out:
# universal nightside temperature hot jupiters due nocturnal clouds dylan keating department physics mcgill university 3600 rue university montreal qc h3a 2t8 nicolas b cowan department physics mcgill university 3600 rue university montreal qc h3a 2t8 department earth planetary sciences mcgill university 3450 rue university montreal qc h3a 0e8 nightsides synchronously rotating planets sensitive probes atmospheric heat transport detecting thermal flux nightside planet means energy transported dayside invert orbital phase curves longitudinally resolved brightness distributions order estimate nightside effective temperatures twelve hot jupiters fullorbit infrared phase curves find although dayside temperatures hot jupiters proportional irradiation temperatures nightside temperatures typical hot jupiters approximately 1000 k three exceptions wasp12b wasp33b wasp103b ultrahot jupiters planets dayside temperatures hot enough dissociate molecular hydrogen models predict much varied nightside temperatures observe energy balance models provide better fit observations wave propagation negligible heat transport alternatively relatively uniform nightside temperatures hot jupiters could due thick clouds mineral sulfide clouds sufficiently large particles could explain uniform nightside temperature well relatively featureless nightside spectra planets close giant exoplanetshot jupiterson circular orbits expected tidally locked synchronous rotation permanent daysides face host stars permanent nightsides face darkness space diskintegrated planetary flux phases planets orbit used determine effective temperature visible part planet phase full orbit infrared phase curves published twelve hot jupiters circular orbits wasp14b highest eccentricity sample general circulation models using small eccentricity predict negligible differences planetary circulation patterns compared circular orbits purposes treat orbits wasp14b lower eccentricity planets circular corot2b hatp7b hd 149026b hd 189733b hd 209458b wasp12b wasp14b wasp18b wasp19b wasp33b wasp43b wasp103b previous estimates daytonight heat recirculation hot jupiters parameterized calculated quantity using diskintegrated brightnessand hence apparent temperatureinferred phase variations studies found trend planets higher irradiation temperatures lower heat recirculation efficiencies planets receiving flux tend hotter hence shorter radiative timescales thus radiate faster winds advect heat around planet recently performed similar analysis found trend heat recirculation irradiation temperature monotonic phase offsets heat recirculation decrease increasing irradiation temperature begin increase irradiation temperature around 3400k study date however considered trends nightside temperatures hot jupiters even though direct probe heat transport planet circular edgeon orbit orbital phase curve inverted longitudinal brightness map many hot jupiters fit criteria first exoplanet map hd 189733b 8m showed eastward shifted hotspot planet line theoretical predictions equatorial superrotating jets exception hd 189733b 55 cancri e corot2b wasp43b phase curves fit published without considering brightness maps could produced fact planets published phase curves negative near transit certain wavelengths implying unphysical diskintegrated nightside flux case hatp7b wasp14b initial fits wasp43b planets strictly positive phase curves imply negative brightness maps wasp12b wasp18b wasp19b wasp103b methods section appendix describe deal unphysical phase curves maps described methods invert published phase curves twelve planets survey longitudinal brightness maps obtain dayside nightside effective temperatures fignightside plot temperatures versus irradiation temperature stellar effective temperature stellar radius semimajor axis use irradiation instead traditional equilibrium temperature latter presumes perfect heat redistribution poor assumption hot jupiters nine planets k nightside temperatures approximately 1000k exhibit ...

# %%
word2vec = Word2Vec(test_paper, min_count=2)
# Out:
# c:\users\gibso\appdata\local\programs\python\python36\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "
